# %%
# Import the Libraries
import numpy as np
import pandas as pd

# %%
# import the data set
rawdf=pd.read_csv("D:\\Downloads\\archive\\Bank Customer Churn Prediction.csv")

# %%
# Check the file 
rawdf
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 0        15634602           619   France  Female   42       2       0.00
# 1        15647311           608    Spain  Female   41       1   83807.86
# 2        15619304           502   France  Female   42       8  159660.80
# 3        15701354           699   France  Female   39       1       0.00
# 4        15737888           850    Spain  Female   43       2  125510.82
# ...           ...           ...      ...     ...  ...     ...        ...
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
# check the column names
rawdf.columns
# Out:
# Index(['customer_id', 'credit_score', 'country', 'gender', 'age', 'tenure',
#        'balance', 'products_number', 'credit_card', 'active_member',
#        'estimated_salary', 'churn'],
#       dtype='object')

# %%
# check the shape of data set
print("Number of column :",rawdf.shape[1])
print("Number of rows :",rawdf.shape[0])
# Out:
# Number of column : 12
# Number of rows : 10000

# %%
# check the information 
rawdf.info()

# 2 column in object
# 8 column in int
# 2 column in float valUE
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       10000 non-null  int64
#  1   credit_score      10000 non-null  int64
#  2   country           10000 non-null  object
#  3   gender            10000 non-null  object
#  4   age               10000 non-null  int64
#  5   tenure            10000 non-null  int64
#  6   balance           10000 non-null  float64
#  7   products_number   10000 non-null  int64
#  8   credit_card       10000 non-null  int64
#  9   active_member     10000 non-null  int64
#  10  estimated_salary  10000 non-null  float64
#  11  churn             10000 non-null  int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %%
# Describe the data set
rawdf.describe()
# Out:
#         customer_id  credit_score           age        tenure        balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        products_number  credit_card  active_member  estimated_salary  \
# count     10000.000000  10000.00000   10000.000000      10000.000000
# mean          1.530200      0.70550       0.515100     100090.239881
# ...

# %%
# we don't have a missing value
rawdf.isna().sum()
# Out:
# customer_id         0
# credit_score        0
# country             0
# gender              0
# age                 0
# tenure              0
# balance             0
# products_number     0
# credit_card         0
# active_member       0
# estimated_salary    0
# churn               0
# dtype: int64

# %%
# starting five entry
rawdf.head()
# Out:
#    customer_id  credit_score country  gender  age  tenure    balance  \
# 0     15634602           619  France  Female   42       2       0.00
# 1     15647311           608   Spain  Female   41       1   83807.86
# 2     15619304           502  France  Female   42       8  159660.80
# 3     15701354           699  France  Female   39       1       0.00
# 4     15737888           850   Spain  Female   43       2  125510.82
#
#    products_number  credit_card  active_member  estimated_salary  churn
# 0                1            1              1         101348.88      1
# 1                1            0              1         112542.58      0
# 2                3            1              0         113931.57      1
# 3                2            0              0          93826.63      0
# 4                1            1              1          79084.10      0

# %%
# Ending five entry
rawdf.tail()
# Out:
#       customer_id  credit_score  country  gender  age  tenure    balance  \
# 9995     15606229           771   France    Male   39       5       0.00
# 9996     15569892           516   France    Male   35      10   57369.61
# 9997     15584532           709   France  Female   36       7       0.00
# 9998     15682355           772  Germany    Male   42       3   75075.31
# 9999     15628319           792   France  Female   28       4  130142.79
#
#       products_number  credit_card  active_member  estimated_salary  churn
# 9995                2            1              0          96270.64      0
# 9996                1            1              1         101699.77      0
# 9997                1            0              1          42085.58      1
# 9998                2            1              0          92888.52      1
# 9999                1            1              0          38190.78      0

# %%
rawdf.value_counts()
# Out:
# customer_id  credit_score  country  gender  age  tenure  balance    products_number  credit_card  active_member  estimated_salary  churn
# 15565701     698           Spain    Female  39   9       161993.89  1                0            0              90212.38          0        1
# 15732281     680           Germany  Male    34   6       146422.22  1                1            0              67142.97          1        1
# 15732199     837           Spain    Male    31   9       104678.62  1                0            1              50972.60          0        1
# 15732202     615           France   Male    34   1       83503.11   2                1            1              73124.53          1        1
# 15732235     662           France   Male    64   0       98848.19   1                0            1              42730.12          0        1
# ...

# %%
rawdf.count()
# Out:
# customer_id         10000
# credit_score        10000
# country             10000
# gender              10000
# age                 10000
# tenure              10000
# balance             10000
# products_number     10000
# credit_card         10000
# active_member       10000
# estimated_salary    10000
# churn               10000
# dtype: int64

# %%
# CHURN
rawdf['churn'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: churn, dtype: int64

# %%
for i in rawdf.columns:
    dis = len(rawdf[i].unique())
    print(f"{i}-{dis}")
    
# is se hume column ke unique value ka count mile hain.
# Out:
# customer_id-10000
# credit_score-460
# country-3
# gender-2
# age-70
# tenure-11
# balance-6382
# products_number-4
# credit_card-2
# active_member-2
# estimated_salary-9999
# churn-2

# %%
# CHURN IS A DEPENDENT COLUMN AND REST OF THE COLUMN IS INDEPENDENT COLUMN.

# %%
rawdf.drop(columns=["customer_id"],inplace=True)

# %%
rawdf.columns
# Out:
# Index(['credit_score', 'country', 'gender', 'age', 'tenure', 'balance',
#        'products_number', 'credit_card', 'active_member', 'estimated_salary',
#        'churn'],
#       dtype='object')

# %%
rawdf['country'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: country, dtype: int64

# %%
rawdf["gender"].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: gender, dtype: int64

# %%
rawdf['gender'].replace({"Male":0,"Female":1},inplace=True)

# MALE DENOTED TO 0 & FEMALE DENOTE TO 1

# %%
rawdf['gender'].value_counts()
# Out:
# 0    5457
# 1    4543
# Name: gender, dtype: int64

# %%
# GRAPHS

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(4,5))
rawdf['churn'].value_counts().plot.pie(autopct="%1.0f%%")
plt.show()

# %%
# COUNTRY
plt.figure(figsize=(13,4))
sns.countplot(data=rawdf,x='country',hue='churn',palette='magma_r')
plt.show()

# %%
# GENDER
plt.figure(figsize=(8,4))
sns.countplot(data=rawdf,x='gender',hue='churn',palette='Accent_r')
plt.show()

# %%
##################
###### DISTPLOT GRAPH #######
##################

# %%
# CREDIT SCORE
sns.distplot(rawdf['credit_score'])
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# GENDER
sns.distplot(rawdf['gender'])
plt.title("GENDER COLUMN")
plt.legend('MF')
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# AGE
sns.distplot(rawdf['age'])
plt.title("AGE COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# TENURE
sns.distplot(rawdf['tenure'])
plt.title("TENURE COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# BALANCE
sns.distplot(rawdf['balance'])
plt.title("BALANCE COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# PRODUCT NUMBER
sns.distplot(rawdf['products_number'])
plt.title("PRODUCTS NUMBER COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# CREDIT CARD
sns.distplot(rawdf['credit_card'])
plt.title("CREDIT CARD COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ACTIVE MEMBER
sns.distplot(rawdf['active_member'])
plt.title("ACTIVE MEMBER COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# ESTIMATED SALARY
sns.distplot(rawdf['estimated_salary'])
plt.title("ESTIMATED SALARY COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# CHURN
sns.distplot(rawdf['churn'])
plt.title("CHURN COLUMN")
plt.show()
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
##################################################
############# BOXPLOT -- TO CHECK THE OUTLIERS  ############
#################################################

# %%
# CREDIT SCORE
sns.boxplot(y=rawdf['credit_score'])
plt.title("CREDIT SCORE COLUMN")
plt.show()

# %%
# AGE
sns.boxplot(y=rawdf['age'])
plt.title("AGE COLUMN")
plt.show()

# %%
# TENURE
sns.boxplot(y=rawdf['tenure'])
plt.title("TENURE COLUMN")
plt.show()

# %%
# BALANCE
sns.boxplot(y=rawdf['balance'])
plt.title("BALANCE COLUMN")
plt.show()

# %%
# PRODUCT NUMBER
sns.boxplot(y=rawdf['products_number'])
plt.title("PRODUCTS NUMBER COLUMN")
plt.show()

# %%
# CREDIT CARD
sns.boxplot(y=rawdf['credit_card'])
plt.title("CREDIT CARD COLUMN")
plt.show()

# %%
# ACTIVE MEMBER
sns.boxplot(y=rawdf['active_member'])
plt.title("ACTIVE MEMBER COLUMN")
plt.show()

# %%
# ESTIMATED SALARY
sns.boxplot(y=rawdf['estimated_salary'])
plt.title("ESTIMATED SALARY COLUMN")
plt.show()

# %%
# CHURN
sns.boxplot(y=rawdf['churn'])
plt.title("CHURN COLUMN")
plt.show()

# %%
#####################
########### SCATTER PLOT ############
#######################

# %%
# CREDIT SCORE
sns.scatterplot(data=rawdf,x='credit_score',y='age',hue='churn')
plt.show()

# %%
# BALANCE 
sns.scatterplot(data=rawdf,x='balance',y='age',hue='churn')
# Out:
# <AxesSubplot:xlabel='balance', ylabel='age'>

# %%
# ESTIMATED SALARY
sns.scatterplot(data=rawdf,x='estimated_salary',y='age',hue='churn')
# Out:
# <AxesSubplot:xlabel='estimated_salary', ylabel='age'>

# %%
# PAIRPLOT
sns.pairplot(rawdf)

# %%
# CHECK THE CATEGORICAL COLUMN IN DATA FRAME
categr_val=rawdf.columns[rawdf.dtypes=='object']
categr_val
# Out:
# Index(['country'], dtype='object')

# %%
# check the duplicate values in the data set.
rawdf.duplicated().sum()

# WE DON'T HAVE A DUPLICATED VALUES IN THIS DATA FRAME
# Out:
# 0

# %%
# CORRELATION
corrdf=rawdf.corr()
corrdf
# Out:
#                   credit_score    gender       age    tenure   balance  \
# credit_score          1.000000  0.002857 -0.003965  0.000842  0.006268
# gender                0.002857  1.000000  0.027544 -0.014733 -0.012087
# age                  -0.003965  0.027544  1.000000 -0.009997  0.028308
# tenure                0.000842 -0.014733 -0.009997  1.000000 -0.012254
# balance               0.006268 -0.012087  0.028308 -0.012254  1.000000
# products_number       0.012238  0.021859 -0.030680  0.013444 -0.304180
# credit_card          -0.005458 -0.005766 -0.011721  0.022583 -0.014858
# active_member         0.025651 -0.022544  0.085472 -0.028362 -0.010084
# estimated_salary     -0.001384  0.008112 -0.007201  0.007784  0.012797
# churn                -0.027094  0.106512  0.285323 -0.014001  0.118533
#
#                   products_number  credit_card  active_member  \
# credit_score             0.012238    -0.005458       0.025651
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corrdf,annot=True,cmap='copper_r')
# Out:
# <AxesSubplot:>

# %%
rawdf.shape
# Out:
# (10000, 11)

# %%
# DUMMY VARIABLE 
fulldf=pd.get_dummies(rawdf,drop_first=True)

# %%
fulldf.shape
# Out:
# (10000, 12)

# %%
from statsmodels.api import add_constant

# %%
fulldf1=add_constant(fulldf)

# %%
fulldf1.shape
# Out:
# (10000, 13)

# %%
fulldf1.head()
# Out:
#    const  credit_score  gender  age  tenure    balance  products_number  \
# 0    1.0           619       1   42       2       0.00                1
# 1    1.0           608       1   41       1   83807.86                1
# 2    1.0           502       1   42       8  159660.80                3
# 3    1.0           699       1   39       1       0.00                2
# 4    1.0           850       1   43       2  125510.82                1
#
#    credit_card  active_member  estimated_salary  churn  country_Germany  \
# 0            1              1         101348.88      1                0
# 1            0              1         112542.58      0                0
# 2            1              0         113931.57      1                0
# 3            0              0          93826.63      0                0
# 4            1              1          79084.10      0                0
#
#    country_Spain
# 0              0
# 1              1
# 2              0
# 3              0
# ...

# %%
# splitting the data set into train & test
# we are separte/split the train & test data ,70% to 30%

# %%
from sklearn.model_selection import train_test_split

# %%
traindf,testdf=train_test_split(fulldf1,train_size=0.7,random_state=2410)

# %%
traindf.shape
# Out:
# (7000, 13)

# %%
testdf.shape
# Out:
# (3000, 13)

# %%
# CONVERTING INTO DEP. & INDEPENDENT VARIABLE

# %%
trainX=traindf.drop(['churn'],axis=1).copy()

# %%
trainY=traindf['churn']

# %%
testX=testdf.drop(['churn'],axis=1).copy()

# %%
testY=testdf['churn']

# %%
print(trainX.shape)
# Out:
# (7000, 12)

# %%
print(trainY.shape)
# Out:
# (7000,)

# %%
print(testX.shape)
# Out:
# (3000, 12)

# %%
print(testY.shape)
# Out:
# (3000,)

# %%
##############################
###### VIF  ################

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
tempMaxVIF = 5 # The VIF that will be calculated at EVERY iteration in while loop
maxVIFCutoff = 5 # 5 is recommended cutoff value for linear regression
trainXCopy = trainX.copy()
counter = 1
highVIFColumnNames = []

while (tempMaxVIF >= maxVIFCutoff):
    
    #print(counter)
    
    # Create an empty temporary df to store VIF values
    tempVIFDf = pd.DataFrame()
    
    # Calculate VIF using list comprehension
    tempVIFDf['VIF'] = [variance_inflation_factor(trainXCopy.values, i) for i in range(trainXCopy.shape[1])]
        
        
   # Create a new column "Column_Name" to store the col names against the VIF values from list comprehension
    tempVIFDf['Column_Name'] = trainXCopy.columns
    
    # Drop NA rows from the df - If there is some calculation error resulting in NAs
    tempVIFDf.dropna(inplace=True)
    
    # Sort the df based on VIF values, then pick the top most column name (which has the highest VIF)
    tempColumnName = tempVIFDf.sort_values(["VIF"], ascending = False).iloc[0,1]
    # tempColumnName = tempVIFDf.sort_values(["VIF"], ascending = True)[-1:]["Column_Name"].values[0]
    
    # Store the max VIF value in tempMaxVIF
    tempMaxVIF = tempVIFDf.sort_values(["VIF"], ascending = False).iloc[0,0]
    # tempMaxVIF = tempVIFDf.sort_values(["VIF"])[-1:]["VIF"].values[0]
    
    print(tempColumnName)
    
    if (tempMaxVIF >= maxVIFCutoff): # This condition will ensure that columns having VIF lower than 5 are NOT dropped
        
        # Remove the highest VIF valued "Column" from trainXCopy. As the loop continues this step will keep removing highest VIF columns one by one 
        trainXCopy = trainXCopy.drop(tempColumnName, axis = 1)    
        highVIFColumnNames.append(tempColumnName)
    
    counter = counter + 1

highVIFColumnNames
# Out:
# const
# credit_score
# age
# products_number
# estimated_salary
# ['const', 'credit_score', 'age', 'products_number']

# %%
highVIFColumnNames.remove('const')

# %%
highVIFColumnNames
# Out:
# ['credit_score', 'age', 'products_number']

# %%
# GROUP BY

# %%
x= pd.DataFrame(rawdf.groupby(['churn'])['churn'].count())

# %%
x
# Out:
#        churn
# churn
# 0       7963
# 1       2037

# %%
# LINEAR REGRESSION

# %%
# MODEL BULDING
from statsmodels.api import OLS
M1=OLS(trainY,trainX).fit()    # dependent var. & indep. var.

# %%
M1.summary()
# we can see the model summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  churn   R-squared:                       0.143
# Model:                            OLS   Adj. R-squared:                  0.142
# Method:                 Least Squares   F-statistic:                     106.1
# Date:                Fri, 14 Jul 2023   Prob (F-statistic):          9.63e-225
# Time:                        21:46:28   Log-Likelihood:                -3018.6
# No. Observations:                7000   AIC:                             6061.
# Df Residuals:                    6988   BIC:                             6143.
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
# PREDUCTION
test_predict=M1.predict(testX)

# %%
test_predict[0:5]
# Out:
# 7035    0.342772
# 8085    0.121438
# 9548    0.209821
# 5119    0.045297
# 9057    0.094377
# dtype: float64

# %%
# MODEL DIGONOSTICST

# %%
# SCATTER PLOT -- model.fittedvalue()(predited value) & model.resid(error)

# %%
sns.distplot(M1.resid)
# Out:
# C:\Users\15-R\anaconda3.a\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
# MODEL EVALUATION

# %%
# RMSE -- root mean square error

# %%
np.sqrt(np.mean((testY-test_predict)**2))
# Out:
# 0.36846899755754825

# %%
# MAPE --- mean absolute percentage error

# %%
(np.mean(np.abs((testY-test_predict)/testY)))*100
# Out:
# inf

# %%
# RANDOM FOREST

# %%
# outliers detection and correctrion
# Q1,Q3,IQR=Q3-Q1,LB,UB

# %%
colforOutliers=['credit_score','balance','estimated_salary']
for i in colforOutliers:
    Q1=np.percentile(rawdf[i],25)
    
    Q3=np.percentile(rawdf[i],75)
    
    IQR=Q3-Q1
    
    LB=Q1-1.5*IQR
    UB=Q3-1.5*IQR

# %%
rawdf[i]=np.where(rawdf[i]>UB,UB,rawdf[i])

# %%
rawdf[i]
# Out:
# 0       1809.04125
# 1       1809.04125
# 2       1809.04125
# 3       1809.04125
# 4       1809.04125
#            ...
# 9995    1809.04125
# 9996    1809.04125
# 9997    1809.04125
# 9998    1809.04125
# 9999    1809.04125
# Name: estimated_salary, Length: 10000, dtype: float64

# %%
rawdf[i]=np.where(rawdf[i]<LB,LB,rawdf[i])

# %%
rawdf[i]
# Out:
# 0       1809.04125
# 1       1809.04125
# 2       1809.04125
# 3       1809.04125
# 4       1809.04125
#            ...
# 9995    1809.04125
# 9996    1809.04125
# 9997    1809.04125
# 9998    1809.04125
# 9999    1809.04125
# Name: estimated_salary, Length: 10000, dtype: float64

# %%
# Let as split the data
from sklearn.model_selection import train_test_split

# %%
traindf,testdf=train_test_split(fulldf,train_size=0.7,random_state=2410)

# %%
traindf.shape
# Out:
# (7000, 12)

# %%
testdf.shape
# Out:
# (3000, 12)

# %%
# Model Bulding
from sklearn.tree import DecisionTreeRegressor,plot_tree

# %%
DT1=DecisionTreeRegressor().fit(trainX,trainY)

# %%
DT1
# Out:
# DecisionTreeRegressor()

# %%
plot_tree(DT1)
# Out:
# [Text(0.6955334311921213, 0.9807692307692307, 'X[3] <= 44.5\nsquared_error = 0.162\nsamples = 7000\nvalue = 0.203'),
#  Text(0.5322237363894516, 0.9423076923076923, 'X[6] <= 2.5\nsquared_error = 0.112\nsamples = 5354\nvalue = 0.129'),
#  Text(0.41012827150557085, 0.9038461538461539, 'X[6] <= 1.5\nsquared_error = 0.101\nsamples = 5231\nvalue = 0.113'),
#  Text(0.2711302633482853, 0.8653846153846154, 'X[3] <= 38.5\nsquared_error = 0.144\nsamples = 2578\nvalue = 0.175'),
#  Text(0.1567700043409058, 0.8269230769230769, 'X[10] <= 0.5\nsquared_error = 0.113\nsamples = 1844\nvalue = 0.13'),
#  Text(0.09109571697294169, 0.7884615384615384, 'X[5] <= 68072.797\nsquared_error = 0.094\nsamples = 1417\nvalue = 0.104'),
#  Text(0.026949790189552885, 0.75, 'X[3] <= 29.5\nsquared_error = 0.161\nsamples = 338\nvalue = 0.201'),
#  Text(0.006366661843437997, 0.7115384615384616, 'X[3] <= 18.5\nsquared_error = 0.075\nsamples = 74\nvalue = 0.081'),
# ...

# %%
# PREDUCTION

# %%
DT_predict=DT1.predict(testX)

# %%
DT_predict
# Out:
# array([1., 0., 0., ..., 1., 0., 1.])

# %%
# model evaluation

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(testY,DT_predict)
print(classification_report(testY,DT_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87      2385
#            1       0.49      0.54      0.52       615
#
#     accuracy                           0.79      3000
#    macro avg       0.69      0.70      0.69      3000
# weighted avg       0.80      0.79      0.80      3000

# %%
# DT Purne
DT2=Decision(random_state=2410,min_sample_leaf=500).fit(trainX,trainY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9012\1843109870.py in <module>
#       1 # DT Purne
# ----> 2 DT2=Decision(random_state=2410,min_sample_leaf=500).fit(trainX,trainY)
#
# NameError: name 'Decision' is not defined

# %%
# PLOT

# %%
plot_tree(DT2,frontsize=10,feature_names=trainX.columns,
          filled=True,class_names=['0','1'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9012\1835678243.py in <module>
# ----> 1 plot_tree(DT2,frontsize=10,feature_names=trainX.columns,
#       2           filled=True,class_names=['0','1'])
#
# NameError: name 'DT2' is not defined

# %%
# prediction
DT2_predict=DT2.predict(testX)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9012\3707148383.py in <module>
#       1 # prediction
# ----> 2 DT2_predict=DT2.predict(testX)
#
# NameError: name 'DT2' is not defined

# %%
#Evaluation
print(classification_report(testY,DT2_predict))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9012\2935892130.py in <module>
#       1 #Evaluation
# ----> 2 print(classification_report(testY,DT2_predict))
#
# NameError: name 'DT2_predict' is not defined

# %%
# Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF=RandomForestRegressor(random_state=2410).fit(trainX,trainY)

# %%
RF
# Out:
# RandomForestRegressor(random_state=2410)

# %%
#prediction
RF_predict=RF.predict(testX)

# %%
RF_predict
# Out:
# array([0.33, 0.04, 0.03, ..., 0.33, 0.27, 0.82])

# %%
# EVALUATION

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(testY,RF_predict))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9012\767166254.py in <module>
# ----> 1 print(classification_report(testY,RF_predict))
#
# ~\anaconda3.a\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2108     """
#    2109
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2111
#    2112     if labels is None:
#
# ~\anaconda3.a\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      91
#      92     if len(y_type) > 1:
# ---> 93         raise ValueError(
#      94             "Classification metrics can't handle a mix of {0} and {1} targets".format(
#      95                 type_true, type_pred
#
# ...
